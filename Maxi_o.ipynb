# %% [markdown]
# <a href="https://colab.research.google.com/github/LamZykoss/Intro-a-la-programacion/blob/main/Maxi_o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
print("Ingresa tus datos: ")
print("=================")
vnombre = input("Nombre:")
vedad = int(input("Edad: "))
print("Bienvenido a python")
print("====================")
print("Hola, " +vnombre+ " tienes " + str(vedad)+" años")
# Out:
# Ingresa tus datos:
# ...
# Nombre:maxi
# Edad: 12
# Bienvenido a python
# ...
# Hola, maxi tienes 12 años
